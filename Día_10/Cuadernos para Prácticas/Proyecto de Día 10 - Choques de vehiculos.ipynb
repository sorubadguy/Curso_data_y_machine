# %% [markdown]
# Choques de vehículos
# ----

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Cargar los datos
ruta = 'C:/Dev/Curso_data_y_machine/Día_10/Cuadernos para Prácticas/Obesity_dataset.xlsx'
data = pd.read_excel(ruta)
data.head()
# Out:
#    Sex  Age  Height  Overweight_Obese_Family  Consumption_of_Fast_Food  \
# 0    2   18     155                        2                         2
# 1    2   18     158                        2                         2
# 2    2   18     159                        2                         2
# 3    2   18     162                        2                         2
# 4    2   18     165                        2                         1
#
#    Frequency_of_Consuming_Vegetables  Number_of_Main_Meals_Daily  \
# 0                                  3                           1
# 1                                  3                           1
# 2                                  2                           1
# 3                                  2                           2
# 4                                  2                           1
#
#    Food_Intake_Between_Meals  Smoking  Liquid_Intake_Daily  \
# 0                          3        2                    1
# ...
