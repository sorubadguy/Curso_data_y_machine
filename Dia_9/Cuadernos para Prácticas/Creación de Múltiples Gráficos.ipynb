# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig, axs = plt.subplots(ncols = 2, nrows = 1);

# %%
fig, axs = plt.subplots(ncols = 2, nrows = 1)

axs1 = axs[0]
axs2 = axs[1];

# %%
fig, axs = plt.subplots(ncols = 2, nrows = 1)

axs1 = axs[0]
axs2 = axs[1]

axs1.plot([1,2,3,4], [1,4,9,16])
axs2.scatter([1,2,3,4], [1,4,9,16]);

# %%
fig, axs = plt.subplots(ncols = 2, nrows = 1)

axs1 = axs[0]
axs2 = axs[1]

axs1.plot([1,2,3,4], [1,4,9,16])
axs2.scatter([1,2,3,4], [1,4,9,16])

axs1.set_title("Grafico de linea")
axs2.set_title("Grafico Scatter");
