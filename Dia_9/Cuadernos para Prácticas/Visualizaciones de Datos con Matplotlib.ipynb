# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
numeros = [2,5,1,-4,3]

# %%
plt.plot(numeros);
#! Se puede omitir el plt.show() si en la celda de las importaciones se llama a %matplotlib inline
#! Se debe usar un ; cuando se desee graficar
#plt.show()

# %%
plt.figure(facecolor= 'orange')
plt.plot(numeros);

# %%
plt.subplots(ncols= 2, nrows= 2);

# %%
fig, axs = plt.subplots(ncols= 2, nrows= 2);

# %%
type(fig)
# Out:
# matplotlib.figure.Figure

# %%
type(axs)
# Out:
# numpy.ndarray

# %%
axs[0]
# Out:
# array([<Axes: >, <Axes: >], dtype=object)

# %%
axs[0][0]
# Out:
# <Axes: >

# %%
type(axs[0][0])
# Out:
# matplotlib.axes._axes.Axes
